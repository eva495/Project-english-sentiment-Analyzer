# %%
#CSC Class project on  Sentiment Analyzer: Analyze sentiments behind a phrase
This data is collected and cleaned

# %% [markdown]
# # collect data

# %%
pip install --upgrade tweepy
# Out:
# Requirement already up-to-date: tweepy in c:\users\owner\anaconda3\lib\site-packages (4.13.0)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied, skipping upgrade: oauthlib<4,>=3.2.0 in c:\users\owner\anaconda3\lib\site-packages (from tweepy) (3.2.2)
# Requirement already satisfied, skipping upgrade: requests-oauthlib<2,>=1.2.0 in c:\users\owner\anaconda3\lib\site-packages (from tweepy) (1.3.1)
# Requirement already satisfied, skipping upgrade: requests<3,>=2.27.0 in c:\users\owner\anaconda3\lib\site-packages (from tweepy) (2.28.2)
# Requirement already satisfied, skipping upgrade: charset-normalizer<4,>=2 in c:\users\owner\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (3.1.0)
# Requirement already satisfied, skipping upgrade: urllib3<1.27,>=1.21.1 in c:\users\owner\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (1.26.14)
# Requirement already satisfied, skipping upgrade: idna<4,>=2.5 in c:\users\owner\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2.10)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in c:\users\owner\anaconda3\lib\site-packages (from requests<3,>=2.27.0->tweepy) (2022.12.7)

# %%
import tweepy

# Authentication
consumerKey = "smnegPeIOBfdnaDBZNmU0qLPo"
consumerSecret = "yVlbDlnDP6f3oC0Z94yY3ZHRnqH2piAxRQLKTst3jgsHXrdZuz"
accessToken = "1246515307390230528-2yIYcHhAYUTI2zwAdUTE9OX4IWKfPl"
accessTokenSecret = "2ETXWWxdRgMq0oad68Z98Njy63ObXKRqtEZmJ9MhekFga"
auth = tweepy.OAuthHandler(consumerKey, consumerSecret)
auth.set_access_token(accessToken, accessTokenSecret)
api = tweepy.API(auth)

# %%
import tweepy
import pandas as pd
from textblob import TextBlob
import time
#cleaning the data
import string

api = tweepy.API(auth)

#defining a method to analysze data
def clean_tweet_text(text):
    text = re.sub(r"http\S+", "", text)
    text = re.sub(r"#\S+", "", text)
    text = re.sub(r"@\S+", "", text)
    text = text.translate(str.maketrans("", "", string.punctuation))
    text = text.lower()
    text = re.sub(r"[^\w\s]", "", text)
    return text

# Sentiment Analysis function
def get_sentiment(tweet):
    analysis = TextBlob(tweet)
    if analysis.sentiment.polarity > 0:
        return 'Positive'
    elif analysis.sentiment.polarity == 0:
        return 'Neutral'
    else:
        return 'Negative'

# User inputs
keyword = input("Please enter keyword or hashtag to search:")
noOfTweet = int(input("Please enter how many tweets to analyze:"))

# Create a list of dictionaries to store the tweets' information
tweets = []
for tweet in tweepy.Cursor(api.search_tweets, q=keyword, lang="en").items(noOfTweet):
    try:
        tweet_dict = {}
        tweet_dict['Created At'] = tweet.created_at
        tweet_dict['Tweet Text'] = tweet.text
        tweet_dict['Sentiment'] = get_sentiment(tweet.text)
        tweets.append(tweet_dict)
    except tweepy.TweepError:
        print("Error occurred, waiting for 15 minutes...")
        time.sleep(15 * 60)

# Create a pandas dataframe to store and manipulate the data
df = pd.DataFrame(tweets)

# Print the sentiment value counts
print(df['Sentiment'].value_counts())

# Save the dataframe to a csv file
df.to_csv('tweets.csv', index=False)
# Out:
# C:\Users\Owner\anaconda3\lib\site-packages\pandas\core\computation\expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# Please enter keyword or hashtag to search:WAR
# Please enter how many tweets to analyze:200
# Sentiment
# Positive    77
# Neutral     73
# Negative    50
# Name: count, dtype: int64

# %%
import pandas as pd

# Read the CSV file into a DataFrame
df = pd.read_csv('tweets.csv')

# Print the DataFrame
print(df)
# Out:
#                     Created At
# 0    2023-04-21 06:58:39+00:00  \
# 1    2023-04-21 06:58:39+00:00
# 2    2023-04-21 06:58:39+00:00
# 3    2023-04-21 06:58:39+00:00
# 4    2023-04-21 06:58:39+00:00
# ..                         ...
# 195  2023-04-21 06:57:34+00:00
# 196  2023-04-21 06:57:34+00:00
# 197  2023-04-21 06:57:32+00:00
# 198  2023-04-21 06:57:32+00:00
# 199  2023-04-21 06:57:32+00:00
#
#                                             Tweet Text Sentiment
# 0    RT @pbump: RFK Jr. and Tucker Carlson have the...  Positive
# 1    RT @To_your_c: Eid Mubarak\n\nTo those away fr...  Positive
# 2    @CaviarHeems @TheStudyofWar @georgewbarros ple...   Neutral
# 3    RT @pgkepfidra: We do, War Graves Week coming ...   Neutral
# 4    RT @2219project: The peace conference is start...  Positive
# ..                                                 ...       ...
# 195  @GretaThunberg You know that war is a major co...  Positive
# 196  RT @Suriyakmaps: Ukrainian-Russian war. Day 42...  Positive
# 197  I remember we couldn't wait to rid ourselves o...  Negative
# 198  RT @Africa_Archives: Hanged by the British, at...  Positive
# 199  RT @geoffreyMyers1: Tory Civil War as Cleverly...  Positive
#
# [200 rows x 3 columns]

# %%
#human anotators

# %%
from textblob import TextBlob

# Sample text to analyze
text = "Those who’ve been brutalized by Russia’s illegal war deserve justice, which is why efforts are already"

# Create a TextBlob object
blob = TextBlob(text)

# Get the sentiment polarity (-1 to 1) and subjectivity (0 to 1)
sentiment_polarity = blob.sentiment.polarity

subjectivity = blob.sentiment.subjectivity

# Print the sentiment label based on the polarity
if sentiment_polarity > 0:
    sentiment_label = "Positive"
elif sentiment_polarity == 0:
    sentiment_label = "Neutral"
else:
    sentiment_label = "Negative"

# Print the results
print(f"Text: {text}")
print(f"Sentiment polarity: {sentiment_polarity:.2f}")
print(f"Subjectivity: {subjectivity:.2f}")
print(f"Sentiment label: {sentiment_label}")
# Out:
# Text: Those who’ve been brutalized by Russia’s illegal war deserve justice, which is why efforts are already
# Sentiment polarity: -0.50
# Subjectivity: 0.50
# Sentiment label: Negative

# %%
data cleaning

# %%
df['Tweet Text'] = df['Tweet Text'].apply(lambda x: x.translate(str.maketrans('', '', string.punctuation)))

# %%
df
# Out:
#                     Created At
# 0    2023-04-21 06:58:39+00:00  \
# 1    2023-04-21 06:58:39+00:00
# 2    2023-04-21 06:58:39+00:00
# 3    2023-04-21 06:58:39+00:00
# 4    2023-04-21 06:58:39+00:00
# ..                         ...
# 195  2023-04-21 06:57:34+00:00
# 196  2023-04-21 06:57:34+00:00
# 197  2023-04-21 06:57:32+00:00
# 198  2023-04-21 06:57:32+00:00
# 199  2023-04-21 06:57:32+00:00
#
#                                             Tweet Text Sentiment
# 0    RT pbump RFK Jr and Tucker Carlson have their ...  Positive
# 1    RT Toyourc Eid Mubarak\n\nTo those away from h...  Positive
# 2    CaviarHeems TheStudyofWar georgewbarros please...   Neutral
# 3    RT pgkepfidra We do War Graves Week coming up ...   Neutral
# 4    RT 2219project The peace conference is startin...  Positive
# ..                                                 ...       ...
# 195  GretaThunberg You know that war is a major con...  Positive
# 196  RT Suriyakmaps UkrainianRussian war Day 421\nS...  Positive
# 197  I remember we couldnt wait to rid ourselves of...  Negative
# 198  RT AfricaArchives Hanged by the British at exa...  Positive
# 199  RT geoffreyMyers1 Tory Civil War as Cleverly r...  Positive
#
# [200 rows x 3 columns]

# %%
#removing emojis
import re
import emoji

def remove_emoji(text):
    emoji_pattern = re.compile("["
                               u"\U0001F600-\U0001F64F"  # emoticons
                               u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                               u"\U0001F680-\U0001F6FF"  # transport & map symbols
                               u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                               "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', text)

df['Tweet Text'] = df['Tweet Text'].apply(remove_emoji)

# %%
df
# Out:
#                     Created At
# 0    2023-04-21 06:58:39+00:00  \
# 1    2023-04-21 06:58:39+00:00
# 2    2023-04-21 06:58:39+00:00
# 3    2023-04-21 06:58:39+00:00
# 4    2023-04-21 06:58:39+00:00
# ..                         ...
# 195  2023-04-21 06:57:34+00:00
# 196  2023-04-21 06:57:34+00:00
# 197  2023-04-21 06:57:32+00:00
# 198  2023-04-21 06:57:32+00:00
# 199  2023-04-21 06:57:32+00:00
#
#                                             Tweet Text Sentiment
# 0    RT pbump RFK Jr and Tucker Carlson have their ...  Positive
# 1    RT Toyourc Eid Mubarak\n\nTo those away from h...  Positive
# 2    CaviarHeems TheStudyofWar georgewbarros please...   Neutral
# 3    RT pgkepfidra We do War Graves Week coming up ...   Neutral
# 4    RT 2219project The peace conference is startin...  Positive
# ..                                                 ...       ...
# 195  GretaThunberg You know that war is a major con...  Positive
# 196  RT Suriyakmaps UkrainianRussian war Day 421\nS...  Positive
# 197  I remember we couldnt wait to rid ourselves of...  Negative
# 198  RT AfricaArchives Hanged by the British at exa...  Positive
# 199  RT geoffreyMyers1 Tory Civil War as Cleverly r...  Positive
#
# [200 rows x 3 columns]

# %%
#convert to lowercase
df['Tweet Text'] = df['Tweet Text'].str.lower()

# %%
df
# Out:
#                     Created At
# 0    2023-04-21 06:58:39+00:00  \
# 1    2023-04-21 06:58:39+00:00
# 2    2023-04-21 06:58:39+00:00
# 3    2023-04-21 06:58:39+00:00
# 4    2023-04-21 06:58:39+00:00
# ..                         ...
# 195  2023-04-21 06:57:34+00:00
# 196  2023-04-21 06:57:34+00:00
# 197  2023-04-21 06:57:32+00:00
# 198  2023-04-21 06:57:32+00:00
# 199  2023-04-21 06:57:32+00:00
#
#                                             Tweet Text Sentiment
# 0    rt pbump rfk jr and tucker carlson have their ...  Positive
# 1    rt toyourc eid mubarak\n\nto those away from h...  Positive
# 2    caviarheems thestudyofwar georgewbarros please...   Neutral
# 3    rt pgkepfidra we do war graves week coming up ...   Neutral
# 4    rt 2219project the peace conference is startin...  Positive
# ..                                                 ...       ...
# 195  gretathunberg you know that war is a major con...  Positive
# 196  rt suriyakmaps ukrainianrussian war day 421\ns...  Positive
# 197  i remember we couldnt wait to rid ourselves of...  Negative
# 198  rt africaarchives hanged by the british at exa...  Positive
# 199  rt geoffreymyers1 tory civil war as cleverly r...  Positive
#
# [200 rows x 3 columns]

# %%
#tokenize text
import nltk
nltk.download('punkt')

df['Tweet Text'] = df['Tweet Text'].apply(lambda x: nltk.word_tokenize(x.lower()))
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
df
# Out:
#                     Created At
# 0    2023-04-21 06:58:39+00:00  \
# 1    2023-04-21 06:58:39+00:00
# 2    2023-04-21 06:58:39+00:00
# 3    2023-04-21 06:58:39+00:00
# 4    2023-04-21 06:58:39+00:00
# ..                         ...
# 195  2023-04-21 06:57:34+00:00
# 196  2023-04-21 06:57:34+00:00
# 197  2023-04-21 06:57:32+00:00
# 198  2023-04-21 06:57:32+00:00
# 199  2023-04-21 06:57:32+00:00
#
#                                             Tweet Text Sentiment
# 0    [rt, pbump, rfk, jr, and, tucker, carlson, hav...  Positive
# 1    [rt, toyourc, eid, mubarak, to, those, away, f...  Positive
# 2    [caviarheems, thestudyofwar, georgewbarros, pl...   Neutral
# 3    [rt, pgkepfidra, we, do, war, graves, week, co...   Neutral
# 4    [rt, 2219project, the, peace, conference, is, ...  Positive
# ..                                                 ...       ...
# 195  [gretathunberg, you, know, that, war, is, a, m...  Positive
# 196  [rt, suriyakmaps, ukrainianrussian, war, day, ...  Positive
# 197  [i, remember, we, couldnt, wait, to, rid, ours...  Negative
# 198  [rt, africaarchives, hanged, by, the, british,...  Positive
# 199  [rt, geoffreymyers1, tory, civil, war, as, cle...  Positive
#
# [200 rows x 3 columns]

# %%
#remove stopwords
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

stop_words = set(stopwords.words('english'))

df['Tweet Text'] = df['Tweet Text'].apply(lambda x: [word for word in x if word.lower() not in stop_words])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Owner\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df
# Out:
#                     Created At
# 0    2023-04-21 06:58:39+00:00  \
# 1    2023-04-21 06:58:39+00:00
# 2    2023-04-21 06:58:39+00:00
# 3    2023-04-21 06:58:39+00:00
# 4    2023-04-21 06:58:39+00:00
# ..                         ...
# 195  2023-04-21 06:57:34+00:00
# 196  2023-04-21 06:57:34+00:00
# 197  2023-04-21 06:57:32+00:00
# 198  2023-04-21 06:57:32+00:00
# 199  2023-04-21 06:57:32+00:00
#
#                                             Tweet Text Sentiment
# 0    [rt, pbump, rfk, jr, tucker, carlson, reasons,...  Positive
# 1    [rt, toyourc, eid, mubarak, away, home, 🤍, new...  Positive
# 2    [caviarheems, thestudyofwar, georgewbarros, pl...   Neutral
# 3    [rt, pgkepfidra, war, graves, week, coming, in...   Neutral
# 4    [rt, 2219project, peace, conference, starting,...  Positive
# ..                                                 ...       ...
# 195  [gretathunberg, know, war, major, contributor,...  Positive
# 196  [rt, suriyakmaps, ukrainianrussian, war, day, ...  Positive
# 197  [remember, couldnt, wait, rid, bill, clinton, ...  Negative
# 198  [rt, africaarchives, hanged, british, exactly,...  Positive
# 199  [rt, geoffreymyers1, tory, civil, war, cleverl...  Positive
#
# [200 rows x 3 columns]

# %%
#change to paragraph to check the data
import pandas as pd
import re
import emoji
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

df = pd.read_csv('tweets.csv')

# Define function to preprocess text
def preprocess_text(text):
    # Convert to lowercase
    text = text.lower()
    # Remove URLs
    text = re.sub(r'http\S+', '', text)
    # Remove mentions
    text = re.sub(r'@\w+', '', text)
    # Remove hashtags
    text = re.sub(r'#\w+', '', text)
    # Remove punctuation
    text = re.sub(r'[^\w\s]', '', text)
    # Remove numbers
    text = re.sub(r'\d+', '', text)
    # Convert emojis to text
    text = emoji.demojize(text)
    # Remove emoji characters
    text = re.sub(r':[a-z_]+:', '', text)
    # Tokenize text
    tokens = word_tokenize(text)
    # Remove stopwords
    stop_words = set(stopwords.words('english'))
    tokens = [word for word in tokens if word not in stop_words]
    # Join tokens back